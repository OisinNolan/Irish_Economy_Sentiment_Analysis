# %%
import pandas as pd
import re
import string
import nltk

# %%
articles = pd.read_csv('csv/imgTrial2.csv')

data = pd.read_excel('xlsx/LM.xlsx','Negative', header=None)
data = data[0]
negList = data.tolist()
negList = [x.lower() for x in negList]

data = pd.read_excel('xlsx/LM.xlsx','Positive', header=None)
data = data[0]
posList = data.tolist()
posList = [x.lower() for x in posList]

# %%
def preprocess( s ):
    # Convert text to upper case
    s = s.lower()
    # Connect words that have been cut off by the end of the page
    s = s.replace('-\n', '')
    # Remove numbers
    s = re.sub(r'\d+', '', s)
    s = s.strip()
    # use regex to remove punctuation
    s = re.sub(r'[^\w\s]','',s)
    # Remove stop words
    stop_words = set(nltk.corpus.stopwords.words("english"))
    from nltk.tokenize import word_tokenize
    # Tokenise
    tokens = word_tokenize(s)
    s = [i for i in tokens if not i in stop_words]
    return s

# %%
def getScoreFromArticle( article ):
    
    posCount = 0
    negCount = 0
    for word in article:
        if word in negList:
            negCount += 1
        if word in posList:
            posCount += 1
    
    if posCount + negCount == 0:
        return 0
    
    return (posCount - negCount) / (posCount + negCount)

# %%
articles['score'] = articles.apply(lambda row: getScoreFromArticle(preprocess(str(row.text))), axis=1)

display(articles)
# Out:
#              date                                               text     score
# 0      1859-09-10  Lhe Temes on Irish Poor Law Management :—\n\nI... -0.241379
# 1      1877-06-01  oils\n\nPORTRUSH, |e\nNTEIM ARMS HOTEL.—!\nnew... -1.000000
# 2      1887-08-03  (*he opponents of the Loop Lino mado\ntheir Ia... -0.454545
# 3      1894-11-21  then convinced of the suficioncy of. ih\nprese... -0.478261
# 4      1903-11-27  THE THREATENED LEGAL\nREFORMS.OE OE RE ENO\nSi... -0.333333
# ...           ...                                                ...       ...
# 11975  2010-11-26  Seize the day, harness the seaWith 40 acres of... -0.333333
# 11976  2010-11-26  Global\nVillagersTo say 2010 has been an event... -0.238095
# 11977  2010-11-26  Celtic Tiger period seemed to have been creat-... -0.365854
# 11978  2010-11-26  [ TAX POLICY |Are we ready to wean off FDI?The...  0.100000
# 11979  2010-11-27  Four-year adjustment will bring 4% reduction i... -0.675676
#
# [11980 rows x 3 columns]

# %%
articles["date"] = pd.to_datetime(articles["date"], format="%Y-%m-%d")
articles = articles.set_index([pd.DatetimeIndex(articles["date"])])
articles = articles.sort_index(axis=0, ascending=True)
articles = articles.drop(columns = "date")
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                          Traceback (most recent call last)
# <ipython-input-165-b7b0b6981de2> in <module>
# ----> 1 articles["date"] = pd.to_datetime(articles["date"], format="%Y-%m-%d")
#       2 articles = articles.set_index([pd.DatetimeIndex(articles["date"])])
#       3 articles = articles.sort_index(axis=0, ascending=True)
#       4 articles = articles.drop(columns = "date")
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'

# %%
t = lambda s : pd.Timestamp(s)

monthlyCount = articles.resample("M")
meanScore = monthlyCount.mean()
ax = meanScore.plot(figsize=(20, 10))
ax.set_xlim(t('1970-01-01'), t('2010-01-01'))
ax.set_ylim(-0.5, 0.5)
# Out:
# (-0.5, 0.5)
